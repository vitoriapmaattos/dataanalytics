# %% [markdown]
# <a href="https://colab.research.google.com/github/vitoriapmaattos/dataanalytics/blob/main/Aula_1_Produ%C3%A7%C3%A3o_Hospitalar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisando dados da saúde Hospitalar

# %%
import pandas as pd

# %%
pd.read_csv('/content/sih_cnv_qiuf22354845_166_204_25.csv', encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# <ipython-input-18-9fa6b988463a>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   pd.read_csv('/content/sih_cnv_qiuf22354845_166_204_25.csv', encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
#       Unidade da Federação     2008/Jan      2008/Fev      2008/Mar  \
# 0              11 Rondônia   1388528.39  2.931283e+06  1.541683e+06
# 1                  12 Acre    902416.00  1.497206e+06  1.794028e+06
# 2              13 Amazonas   4735529.42  7.118991e+06  8.196635e+06
# 3               14 Roraima    657889.53  7.779393e+05  7.186880e+05
# 4                  15 Pará  18864744.11  1.955376e+07  2.193734e+07
# 5                 16 Amapá   1120973.34  1.268740e+06  9.746512e+05
# 6             17 Tocantins   3441592.69  4.985689e+06  6.205613e+06
# 7              21 Maranhão  10723506.39  1.355968e+07  1.398514e+07
# ...

# %%
dados = pd.read_csv('/content/sih_cnv_qiuf22354845_166_204_25.csv', encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# <ipython-input-25-9d638889e925>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv('/content/sih_cnv_qiuf22354845_166_204_25.csv', encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")

# %%
dados.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953.84   1406150.68   3065279.01   3231494.61   3117178.63  ...
# 1   1819443.92   1828496.00   2511754.59   2089107.14   2275708.53  ...
# 2   7831399.90   8477273.62   9368858.72   9352532.70   9363099.35  ...
# 3    862347.96    832440.66    996693.09    894271.18    910424.17  ...
# 4  23249952.88  23240687.56  24002223.56  23341218.03  25172261.32  ...
#
#       2023/Mai     2023/Jun     2023/Jul     2023/Ago     2023/Set  \
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 22   43 Rio Grande do Sul  30931325.46  57363420.01  51547794.07  56673338.49
# 23  50 Mato Grosso do Sul   5377392.11   7002472.61   8423933.19   8797487.68
# 24         51 Mato Grosso   4795299.01   8684882.23   7886243.14   8794109.79
# 25               52 Goiás  15310637.29  22258668.68  21442515.75  20921212.45
# 26    53 Distrito Federal   4745919.19   7632480.67   9647203.26  11098732.99
#
#        2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 22  48397733.07  52413429.62  56636376.98  56113054.70  55356224.30  ...
# 23   9770421.80  10905392.18  10249299.82   9671553.45  10218511.05  ...
# 24   9231645.40  10221763.77   9163314.28   9243148.81   9052354.89  ...
# 25  21615970.67  18270043.87  20540517.13  20650730.67  20868443.56  ...
# 26  12891719.72  12850125.67  12565646.74  13710857.89  13165106.20  ...
#
# ...

# %%
dados.mean()
# Out:
# <ipython-input-23-99af3ba13e28>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2023/Set    6.518909e+07
# 2023/Out    6.694171e+07
# 2023/Nov    6.572583e+07
# 2023/Dez    6.553714e+07
# Total       8.578342e+09
# Length: 192, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 195 entries, Unidade da Federação to Total
# dtypes: float64(192), object(3)
# memory usage: 41.3+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# <ipython-input-28-99af3ba13e28>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2023/Set     65189094.24
# 2023/Out     66941705.27
# 2023/Nov     65725826.24
# 2023/Dez     65537138.18
# Total      8578342381.93
# Length: 192, dtype: float64

# %%
dados['2024/Jan']
# Out:
# 0      10516070.26
# 1                -
# 2      15065867.12
# 3       2164371.02
# 4      43689467.84
# 5       3961035.17
# 6        426805.38
# 7      37885708.46
# 8      20541206.34
# 9      61814810.50
# 10     24197408.11
# 11     33490746.90
# 12     84078535.80
# 13     20349028.62
# 14     16082837.55
# 15     94641578.14
# 16    214852257.67
# 17     39634805.09
# 18    119869243.96
# 19    386813086.90
# 20    155308686.22
# 21    101777599.24
# 22    120732038.67
# 23     23959476.62
# 24     21462469.97
# 25     47555420.60
# 26     31878001.55
# Name: 2024/Jan, dtype: object
